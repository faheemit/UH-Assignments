# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("housing.csv")

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df.isna().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df['total_bedrooms'].mean()
# Out:
# 537.8705525375618

# %%
import math

# %%
Newbedrooms = math.floor(df['total_bedrooms'].mean())
Newbedrooms
# Out:
# 537

# %%
df.fillna({
    'total_bedrooms': 537
}, inplace = True)
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df.sample(100)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5221     -118.24     33.95                21.0       1260.0           342.0
# 5935     -117.87     34.15                24.0       5745.0           735.0
# 9743     -121.65     36.77                15.0       2191.0           358.0
# 14833    -117.10     32.67                15.0       1635.0           553.0
# 9420     -122.62     37.85                30.0        833.0           164.0
# ...          ...       ...                 ...          ...             ...
# 11159    -118.01     33.82                31.0       1960.0           380.0
# 11531    -118.09     33.76                26.0       1625.0           440.0
# 5342     -118.44     34.04                16.0         18.0             6.0
# 20118    -120.40     37.92                22.0       1022.0           194.0
# 9524     -123.17     39.18                14.0       2240.0           327.0
#
# ...

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
df.duplicated().any()
# Out:
# False

# %%
df.shape
# Out:
# (20640, 10)

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
sns.countplot(data = df, x = 'ocean_proximity')
# Out:
# <AxesSubplot:xlabel='ocean_proximity', ylabel='count'>

# %%
sns.barplot(x = df['total_rooms'], y = df['housing_median_age'] )
# Out:
# <AxesSubplot:xlabel='total_rooms', ylabel='housing_median_age'>

# %%
sns.histplot(data=df, x="median_house_value", hue="ocean_proximity")
# Out:
# <AxesSubplot:xlabel='median_house_value', ylabel='Count'>

# %%
heat = df.corr()

# %%
sns.heatmap(heat, annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(data=df, x="ocean_proximity", y="median_house_value", color= 'red')
# Out:
# <AxesSubplot:xlabel='ocean_proximity', ylabel='median_house_value'>

# %%
sns.lineplot(data=df, x="households", y="median_house_value", color= 'red')
# Out:
# <AxesSubplot:xlabel='households', ylabel='median_house_value'>

# %%
sns.lineplot(data=df, x="ocean_proximity", y="households", color= 'red')
# Out:
# <AxesSubplot:xlabel='ocean_proximity', ylabel='households'>

# %%
sns.scatterplot(data=df, x="median_house_value", y="households", color= 'red')
# Out:
# <AxesSubplot:xlabel='median_house_value', ylabel='households'>

# %%
sns.barplot(data=df, x="median_house_value", y="households", color= 'red')
# Out:
# <AxesSubplot:xlabel='median_house_value', ylabel='households'>

# %%
sns.pairplot(df, hue = 'median_house_value')

# %%
sns.violinplot(x = 'median_income', y = 'housing_median_age', data = df, hue = 'ocean_proximity' )
# Out:
# <AxesSubplot:xlabel='median_income', ylabel='housing_median_age'>

# %%
grid1 = df

# %%
g = sns.PairGrid(grid1)
g.map_diag(sns.distplot)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)
# Out:
# C:\Users\fahee\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\fahee\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.pairplot(df)
plt.show()

# %%
grid2 = df

# %%
g = sns.PairGrid(grid2)
g.map_diag(sns.distplot)
g.map_upper(sns.histplot)
g.map_lower(sns.barplot)
# Out:
# C:\Users\fahee\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\fahee\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.histplot(df)
plt.xlim(0,4000)
plt.ylim(0,2000)
# Out:
# (0.0, 2000.0)
